# %% [markdown]
# # 🚀 MoE Workbench - Advanced One-Click Launcher
#
# ### ⚙️ IMPORTANT SETUP (Before running):
# 1. **Internet On**: In the right sidebar, go to **Settings** -> **Internet** and toggle it **ON**.
# 2. **Accelerator**: Select **GPU T4 x2** (recommended) or **P100** GPU.
# 3. **Persistence**: Ensure Filesystem is set to **No Persistence** (default) or **Variables only** for faster deployment.

# %%
# 1. Clone Project
import os
repo_url = "https://github.com/kkomyoeminaung/moe-llm-9b-workbench.git"
repo_name = "moe-llm-9b-workbench"

if not os.path.exists(repo_name):
    print(f"📥 Cloning {repo_name}...")
    # !git clone {repo_url}
else:
    print("✅ Project already exists. Updating...")
    # %cd {repo_name}
    # !git pull
    # %cd ..

# %cd {repo_name}

# Verify run file exists
if os.path.exists("run_kaggle.py"):
    print("🚀 Launching Deployment Script...")
    # !python run_kaggle.py
else:
    print("❌ ERROR: run_kaggle.py not found! Make sure you pushed your changes from AI Studio to GitHub.")
